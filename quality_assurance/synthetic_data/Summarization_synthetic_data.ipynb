# %%
# %pip install requests
# Out:
# Requirement already satisfied: requests in /home/miriam/miniconda3/envs/case-dev/lib/python3.10/site-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/miriam/miniconda3/envs/case-dev/lib/python3.10/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/miriam/miniconda3/envs/case-dev/lib/python3.10/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/miriam/miniconda3/envs/case-dev/lib/python3.10/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/miriam/miniconda3/envs/case-dev/lib/python3.10/site-packages (from requests) (2025.7.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import json
import time

# Endpoint of the Ollama server
OLLAMA_URL = "http://192.168.8.18:11434/api/generate"

# Your prompt template
prompt = """
You are generating realistic, emotionally-rich transcripts of calls made to **116**, the national child protection helpline in East Africa.

---

📌 Context:
Callers use 116 to report serious child protection concerns like:
- physical abuse
- emotional abuse
- neglect
- sexual violence
- child marriage
- child labor
- trafficking
- abandonment
- online exploitation
- harmful cultural practices
- exposure to violence
- denial of education
- forced domestic work

A trained counselor responds to each call with empathy, asks questions, assesses urgency, and advises next steps.

---

📞 Example Transcript (long-form, single paragraph):

"Hello? Am I speaking to 116? Yes, this is 116. Thank you for calling. Who am I speaking with? My name is Samuel, I’m calling from Bungoma. I’m worried about my neighbor’s daughter — she’s only 10, and they leave her alone at home every night while they go drinking. Sometimes she cries until late. That sounds very distressing. Has she ever told you what happens? Yes, she said she's scared and that sometimes strangers knock on the door. That’s very concerning, Samuel. Thank you for speaking up. Do her parents come back in the morning? Sometimes they don’t show up till the next day. She’s hungry and hasn’t gone to school in weeks. Okay. That’s a clear case of neglect. We’ll involve the area Children’s Officer and also get in touch with a local child protection volunteer. Do you think she’d be safe staying with you until someone comes? Yes, we already help her sometimes. Alright. We’ll act on this immediately. Please stay close by and we’ll follow up shortly."

---

🧠 Your Task:

Now generate a new, realistic transcript of a child protection call. Follow these instructions:

- Write in **one long, natural-sounding paragraph**
- Use a **conversational, spoken tone**
- Include empathy, clarifying questions, and referral steps
- Vary the names, locations, phrasing, and issue types
- Do **not** use speaker labels, line breaks, or numbered steps
- Avoid unrelated numbers, markdown symbols, or formatting

---

After writing the full transcript, return **only** a valid JSON object with the following fields:

{
  "transcript": "<The full conversation as one paragraph>",
  "summary": "<A short narrative summary of what happened in the call. Use the structure: '<Reporter name> from <location> called to report a <case category> case involving <victim>. The incident involves <perpetrator>. The case was categorized as <priority> and referred to <referral>. Intervention: <intervention>.'>",
  "name": "<First name of caller>",
  "location": "<Town, county, or region>",
  "issue": "<The main issue reported (e.g., child marriage, neglect)>",
  "victim": "<Who is affected (e.g., 12-year-old girl, caller’s cousin)>",
  "perpetrator": "<Who is responsible (e.g., stepfather, aunt)>",
  "referral": "<What support the counselor recommended (e.g., Children’s Officer, police)>",
  "category": "<Case type (e.g., physical abuse, child labor)>",
  "priority": "<low | medium | high — based on urgency and risk>",
  "intervention": "<What action was taken or recommended>"
}

Return only the JSON object — no explanations, no markdown, no extra text.
"""

# Output file
output_file = "mistral_helpline_data_ollama2.jsonl"
num_samples = 10000

with open(output_file, "w") as f:
    for i in range(num_samples):
        print(f"📞 Generating record {i+1}/{num_samples}...")

        try:
            payload = {
                "model": "mistral",
                "prompt": prompt,
                "stream": False
            }

            res = requests.post(OLLAMA_URL, json=payload)
            res.raise_for_status()

            output_text = res.json()["response"]
            print (output_text)

            # Parse and check
            data = json.loads(output_text)
            required_keys = [
                "transcript", "summary", "name", "location", "issue",
                "victim", "perpetrator", "referral", "category", "priority", "intervention"
            ]

            if all(k in data for k in required_keys):
                f.write(json.dumps(data) + "\n")
            else:
                print("⚠️ Missing fields in sample", i+1)
        except Exception as e:
            print("❌ Error:", str(e))

        time.sleep(0.2)

print(f"\n✅ Done! Saved {num_samples} records to: {output_file}")
# Out:
# 📞 Generating record 1/1000...
#  {
#   "transcript": "Hello? Yes, this is 116. A man from Mwanza called, deeply concerned about his niece. She's barely eight and has been forced to work in a brick factory since her parents passed away. He heard that her uncle, who lives nearby, might be involved. This sounds tragic. The caller hasn't seen the girl for weeks but thinks she could be hidden somewhere around their old family home. That's a clear case of child labor. We'll involve the local Children's Officer and reach out to a child welfare organization. If possible, he suggested searching for her there. We’ll act on this immediately and get back to him soon.",
#   "summary": "'John from Mwanza called to report a child labor case involving an 8-year-old girl, his niece. The incident involves her uncle. The case was categorized as high and referred to the local Children’s Officer and a child welfare organization. Intervention: Search for the victim if possible.'",
#   "name": "John",
#   "location": "Mwanza",
#   "issue": "child labor",
#   "victim": "8-year-old girl, caller's niece",
#   "perpetrator": "uncle",
#   "referral": "local Children’s Officer and child welfare organization",
#   "category": "child labor",
#   "priority": "high",
#   "intervention": "Search for the victim if possible"
# }
# 📞 Generating record 2/1000...
#  {
#   "transcript": "Good day, I believe you've reached 116? Yes, this is 116. How may I assist you today? Hello, my name is Grace from Kisumu. I'm concerned about my nephew, he's just seven and seems to be undergoing some form of emotional abuse by his stepfather. He's become very quiet and doesn't want to play like before. That sounds troubling, Grace. Have there been any direct signs or comments that suggest emotional abuse? Yes, I've noticed him crying frequently and he mentions being scared when the stepfather is around. That’s concerning, Grace. It would be helpful if you could provide more details about these incidents. This case involves a 7-year-old boy being emotionally abused by his stepfather. The case was categorized as medium. I'll recommend reaching out to the local Children's Officer and a child psychologist for further assistance. Intervention: They will offer counseling services for both the child and the family.",
#   "summary": "'Grace from Kisumu called to report an emotional abuse case involving a 7-year-old boy by his stepfather. The case was categorized as medium and referred to the local Children's Officer and a child psychologist. Intervention: They will offer counseling services for both the child and the family.'",
#   "name": "Grace",
#   "location": "Kisumu",
#   "issue": "emotional abuse",
#   "victim": "7-year-old boy",
#   "perpetrator": "stepfather",
#   "referral": "local Children's Officer and a child psychologist",
#   "category": "child protection",
#   "priority": "medium",
#   "intervention": "counseling services for both the child and the family"
# }
# 📞 Generating record 3/1000...
#  {
#   "transcript": "Hello? This is 116. Thank you for reaching out. I can see you're from Kisumu, Maureen. You've called about a concerning situation with your nephew. He's only six and seems to be subjected to physical abuse by his stepfather. What exactly have you observed, Maureen? Yes, he's come home with bruises several times now. That's alarming. Have there been any witnesses or reports made? No, not yet. It's important we take action promptly. This case is categorized as high and will be referred to the police for further investigation. In the meantime, we advise you to seek medical attention for your nephew immediately and document any signs of abuse.",
#   "summary": "Maureen from Kisumu called to report a physical abuse case involving her six-year-old nephew. The incident involves the stepfather. The case was categorized as high and referred to the police. Intervention: Seek medical attention for the victim and document any signs of abuse.",
#   "name": "Maureen",
#   "location": "Kisumu",
#   "issue": "Physical abuse",
#   "victim": "Six-year-old nephew",
#   "perpetrator": "Stepfather",
#   "referral": "Police",
#   "category": "Physical abuse",
#   "priority": "high",
#   "intervention": "Seek medical attention for the victim and document any signs of abuse"
# }
# 📞 Generating record 4/1000...
#  {
#   "transcript": "Hi, I'm reaching out to 116. Yes, hello. I’m Jane from Kisumu and I have a concern about my brother's daughter. She's only nine, and she's being forced into domestic work at home. She comes home with bruises sometimes. Oh, that sounds awful. Has anyone asked her what happens? Yes, she told me once that her stepfather beats her when she doesn't finish the chores quickly enough. That’s very concerning, Jane. Thank you for bringing this to our attention. Is there someone else in the family who could take care of her temporarily? My sister lives nearby and could help. Alright. We’ll escalate this matter to the local Children's Officer and suggest they involve the police. This case is categorized as high, given the physical abuse involved. Intervention: immediate investigation and potential arrest of the stepfather.",
#   "summary": "Jane from Kisumu called to report a physical abuse case involving a 9-year-old girl, her brother's daughter. The incident involves the stepfather. The case was categorized as high and referred to the local Children’s Officer and police. Intervention: immediate investigation and potential arrest of the stepfather.",
#   "name": "Jane",
#   "location": "Kisumu",
#   "issue": "physical abuse",
#   "victim": "9-year-old girl, brother's daughter",
#   "perpetrator": "stepfather",
#   "referral": "local Children’s Officer and police",
#   "category": "physical abuse",
#   "priority": "high",
#   "intervention": "immediate investigation and potential arrest of the stepfather"
# }
# 📞 Generating record 5/1000...
#  {
#   "transcript": "Hello? Yes, you've reached 116. Thank you for your call. I can see you're from Mombasa. You're reporting a child labor case, isn't that correct? You mentioned your 14-year-old brother is forced to work in a local factory since his father passed away. This sounds very concerning. Is there any danger or mistreatment involved? Yes, he's not given proper meals and often works long hours. That's indeed a severe violation of child rights. We'll immediately involve the Children’s Officer for investigation. It would be beneficial if your brother could stay with a trusted relative until the situation is resolved. Is there someone safe you can rely on? Yes, my sister lives in town and she has agreed to help. Alright, we'll act swiftly. Please keep us updated and expect our follow-up call soon.",
#   "summary": "Anonymous from Mombasa called to report a child labor case involving the caller’s 14-year-old brother. The incident involves the boy being forced to work in a factory by his father's absence. The case was categorized as high and referred to the Children’s Officer. Intervention: Relocating the victim to a safe relative.",
#   "name": "Anonymous",
#   "location": "Mombasa",
#   "issue": "Child labor",
#   "victim": "14-year-old brother",
#   "perpetrator": "Father's absence",
#   "referral": "Children’s Officer",
#   "category": "Forced labor",
#   "priority": "high",
#   "intervention": "Relocating the victim to a safe relative"
# }
# 📞 Generating record 6/1000...
#  {
#   "transcript": "Hello? Am I speaking to 116? Yes, this is 116. Thank you for calling. A concerned citizen from Mombasa called to report a case of emotional abuse involving a 7-year-old boy. The incident involves his mother. The case was categorized as high and referred to the Children’s Officer and local child protection volunteer. The boy has been showing signs of depression, fear, and withdrawal after being frequently ridiculed by his mother. The caller mentioned that they've witnessed this behavior for over a month now. They asked if there’s anything they can do to help and were advised to document any further instances of abuse, keep the boy safe, and encourage him to share his feelings.",
#   "summary": "Concerned citizen from Mombasa called to report an emotional abuse case involving a 7-year-old boy. The incident involves his mother. The case was categorized as high and referred to the Children’s Officer and local child protection volunteer. Intervention: Document further instances of abuse, keep the boy safe, and encourage him to share his feelings.",
#   "name": "Concerned citizen",
#   "location": "Mombasa",
#   "issue": "Emotional abuse",
#   "victim": "7-year-old boy",
#   "perpetrator": "Mother",
#   "referral": "Children’s Officer and local child protection volunteer",
#   "category": "Emotional abuse",
#   "priority": "High",
#   "intervention": "Document further instances of abuse, keep the boy safe, and encourage him to share his feelings."
# }
# 📞 Generating record 7/1000...
#  {
#   "transcript": "Hello? This is 116. Thank you for reaching out. I can hear a lot of worry in your voice. You're calling from Mombasa? Yes, that's correct. You have concerns about your niece, right? She's just six and her mother keeps locking her up at home all day. The poor child barely gets any food. Oh dear, that sounds terrible. Has anyone spoken to the mother about this yet? No, not really. I see. Well, it's important we act quickly. This is a clear case of neglect. We'll contact the Children's Officer in your area and also connect with a local child protection volunteer. It would be safer for your niece to stay with someone she trusts until help arrives. Yes, you mentioned that your sister sometimes lets her visit when things are better. That's a good option then. We'll follow up soon.",
#   "summary": "Rose from Mombasa called to report a neglect case involving Rose's six-year-old niece. The incident involves the mother. The case was categorized as high and referred to Children’s Officer and local child protection volunteer. Intervention: Temporarily relocating the victim to a safer place.",
#   "name": "Rose",
#   "location": "Mombasa",
#   "issue": "Neglect",
#   "victim": "Six-year-old niece",
#   "perpetrator": "Mother",
#   "referral": "Children’s Officer and local child protection volunteer",
#   "category": "Neglect",
#   "priority": "High",
#   "intervention": "Temporarily relocating the victim to a safer place"
# }
# 📞 Generating record 8/1000...
#  {
#   "transcript": "Hello, this is 116. Thank you for reaching out. I understand there's a concern about a 5-year-old boy named Isaiah from Mombasa. His mother has been leaving him without food or care while she works long hours at the market. It sounds like he's suffering from neglect. Have there been any noticeable changes in his health or behavior? Yes, he looks weak and isn't attending school anymore. That's quite alarming. We'll report this to the Children's Officer and also connect with a local community healthcare worker. They can provide immediate assistance. It might be beneficial if Isaiah could stay with a trusted relative until help arrives. Yes, his grandmother is willing to take care of him. Alright, we'll act on this promptly. Please keep an eye on him and we'll follow up shortly.",
#   "summary": "Isaiah from Mombasa called to report a neglect case involving a 5-year-old boy. The incident involves his mother. The case was categorized as high and referred to the Children’s Officer and local community healthcare worker. Intervention: Isaiah might be temporarily taken care of by his grandmother.",
#   "name": "Isaiah",
#   "location": "Mombasa",
#   "issue": "Neglect",
#   "victim": "5-year-old boy",
#   "perpetrator": "mother",
#   "referral": "Children’s Officer and local community healthcare worker",
#   "category": "Neglect",
#   "priority": "high",
#   "intervention": "Isaiah might be temporarily taken care of by his grandmother."
# }
# 📞 Generating record 9/1000...
#  {
#   "transcript": "Hello? This is 116. Thank you for calling. I can see it's a distressing situation. You're from Mombasa and reporting your 5-year-old nephew being forced into child labor by his own mother. The boy has been missing school for months, working long hours at a local market instead. This is a clear case of child labor. We'll immediately involve the Children's Officer and reach out to a local child protection volunteer. It seems he feels safer with you since he occasionally visits your home. Yes, we can provide temporary care until help arrives. We'll act swiftly and follow up shortly.",
#   "summary": "John from Mombasa called to report a child labor case involving his 5-year-old nephew. The incident involves the boy's own mother. The case was categorized as high, and referred to the Children’s Officer and local child protection volunteer. Intervention: Providing temporary care at John's home until help arrives.",
#   "name": "John",
#   "location": "Mombasa",
#   "issue": "child labor",
#   "victim": "5-year-old nephew",
#   "perpetrator": "own mother",
#   "referral": "Children’s Officer and local child protection volunteer",
#   "category": "forced labor",
#   "priority": "high",
#   "intervention": "Providing temporary care at John's home until help arrives"
# }
# 📞 Generating record 10/1000...
